# %%
import pandas as pd
import scanpy as sc

# %% [markdown]
# ### row data

# %%
adata=sc.read_10x_mtx("/wrk/jacky/organoid/counts/CRISPR_counts/outs/raw_feature_bc_matrix")
adata
# Out:
# AnnData object with n_obs × n_vars = 502366 × 32285
#     var: 'gene_ids', 'feature_types'

# %%
adata.obs_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 502366 × 32285
#     var: 'gene_ids', 'feature_types'

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
adata.var
# Out:
#                       gene_ids    feature_types
# Xkr4        ENSMUSG00000051951  Gene Expression
# Gm1992      ENSMUSG00000089699  Gene Expression
# Gm19938     ENSMUSG00000102331  Gene Expression
# Gm37381     ENSMUSG00000102343  Gene Expression
# Rp1         ENSMUSG00000025900  Gene Expression
# ...                        ...              ...
# AC124606.1  ENSMUSG00000095523  Gene Expression
# AC133095.2  ENSMUSG00000095475  Gene Expression
# AC133095.1  ENSMUSG00000094855  Gene Expression
# AC234645.1  ENSMUSG00000095019  Gene Expression
# AC149090.1  ENSMUSG00000095041  Gene Expression
#
# [32285 rows x 2 columns]

# %% [markdown]
# ### Filtered data

# %%
adata3=sc.read_10x_mtx("/wrk/jacky/organoid/counts/CRISPR_counts/outs/filtered_feature_bc_matrix")
adata3
# Out:
# AnnData object with n_obs × n_vars = 5776 × 32285
#     var: 'gene_ids', 'feature_types'

# %%
adata2=sc.read_10x_h5("/wrk/jacky/organoid/counts/CRISPR_counts/outs/filtered_feature_bc_matrix.h5")
adata2
# Out:
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 5776 × 32285
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
adata2.obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
#check adata2 features
adata2.obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
adata2.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
import h5py

file_path = '/wrk/jacky/organoid/counts/CRISPR_counts/outs/molecule_info.h5'

# Open the HDF5 file using h5py
with h5py.File(file_path, 'r') as f:
    # Print the available keys/groups in the file
    print(f.keys())


#
# Out:
# <KeysViewHDF5 ['barcode_idx', 'barcode_info', 'barcodes', 'count', 'feature_idx', 'features', 'gem_group', 'library_idx', 'library_info', 'metrics_json', 'umi', 'umi_type']>

# %%
import pandas as pd
df=pd.read_csv("/wrk/jacky/organoid/counts/CRISPR_counts/SI_organoid_KO_genes - For_Bernie.csv",header=None)
df
# Out:
#           0                     1        2
# 0   Ascl2.1  GCGGCGATCTGGAGCAACCG    Ascl2
# 1   Ascl2.2  CGCACCAGAACTCGTAGCAG    Ascl2
# 2   Ascl2.3  GGCTCCAGCGACTCCAGACG    Ascl2
# 3   Ascl2.4  CCAAGTTTACCAGCTTTACG    Ascl2
# 4    Atf3.1  TCAAATACCAGTGACCCAGG     Atf3
# ..      ...                   ...      ...
# 59  Contr.4  ATCCGGGCATAGCGTTTAAA  Control
# 60  Contr.5  GCTTATCGTCATGCGGGTGA  Control
# 61  Contr.6  ACGCTGTTCGTAACCGCGGG  Control
# 62  Contr.7  GCCGTAAGCGGGCCGGTTGA  Control
# 63  Contr.8  TCCTATAATTGAGCGAACGG  Control
#
# [64 rows x 3 columns]

# %%
#name the first coiume pGene, second column barcodes
df.columns=["pGene","barcodes",'status']
df
# Out:
#       pGene              barcodes   status
# 0   Ascl2.1  GCGGCGATCTGGAGCAACCG    Ascl2
# 1   Ascl2.2  CGCACCAGAACTCGTAGCAG    Ascl2
# 2   Ascl2.3  GGCTCCAGCGACTCCAGACG    Ascl2
# 3   Ascl2.4  CCAAGTTTACCAGCTTTACG    Ascl2
# 4    Atf3.1  TCAAATACCAGTGACCCAGG     Atf3
# ..      ...                   ...      ...
# 59  Contr.4  ATCCGGGCATAGCGTTTAAA  Control
# 60  Contr.5  GCTTATCGTCATGCGGGTGA  Control
# 61  Contr.6  ACGCTGTTCGTAACCGCGGG  Control
# 62  Contr.7  GCCGTAAGCGGGCCGGTTGA  Control
# 63  Contr.8  TCCTATAATTGAGCGAACGG  Control
#
# [64 rows x 3 columns]

# %%
adata2.var_names
# Out:
# Index(['Xkr4', 'Gm1992', 'Gm19938', 'Gm37381', 'Rp1', 'Sox17', 'Gm37587',
#        'Gm37323', 'Mrpl15', 'Lypla1',
#        ...
#        'Gm16367', 'AC163611.1', 'AC163611.2', 'AC140365.1', 'AC124606.2',
#        'AC124606.1', 'AC133095.2', 'AC133095.1', 'AC234645.1', 'AC149090.1'],
#       dtype='object', length=32285)

# %%
'Ctnnb1.1' in adata2.var_names
# Out:
# False

# %%
adata2.obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
perturb_list= sorted(list(set(df["pGene"])))
perturb_list
# Out:
# ['Ascl2.1',
#  'Ascl2.2',
#  'Ascl2.3',
#  'Ascl2.4',
#  'Atf3.1',
#  'Atf3.2',
#  'Atf3.3',
#  'Atf3.4',
#  'Contr.1',
#  'Contr.2',
#  'Contr.3',
#  'Contr.4',
#  'Contr.5',
#  'Contr.6',
#  'Contr.7',
#  'Contr.8',
#  'Ctnnb1.1',
#  'Ctnnb1.2',
#  'Ctnnb1.3',
#  'Ctnnb1.4',
#  'Egr1.1',
#  'Egr1.2',
#  'Egr1.3',
#  'Egr1.4',
#  'Ezh2.1',
#  'Ezh2.2',
#  'Ezh2.3',
#  'Ezh2.4',
#  'Gfi1.1',
#  'Gfi1.2',
#  'Gfi1.3',
#  'Gfi1.4',
#  'Hes1.1',
#  'Hes1.2',
#  'Hes1.3',
#  'Hes1.4',
#  'Hnf4g.1',
#  'Hnf4g.2',
#  'Hnf4g.3',
#  'Hnf4g.4',
#  'Klf13.1',
#  'Klf13.2',
#  'Klf13.3',
#  'Klf13.4',
#  'Klf4.1',
#  'Klf4.2',
#  'Klf4.3',
#  'Klf4.4',
#  'Myc.1',
#  'Myc.2',
#  'Myc.3',
#  'Myc.4',
#  'Prc1.1',
#  'Prc1.2',
#  'Prc1.3',
#  'Prc1.4',
#  'Sox9.1',
#  'Sox9.2',
#  'Sox9.3',
#  'Sox9.4',
#  'Spdef.1',
#  'Spdef.2',
#  'Spdef.3',
#  'Spdef.4']

# %%
adata2.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
# Stem
# Lgr5, Olfm4
# Enterocyte
# Alpi
# Goblet
# Muc2
#Paneth
# Lyz1
# Tuft
# Dclk1
# Enteroendocrine
# Chga



'Lyz1' in adata2.var_names
# Out:
# True

# %%
sc.pl.highest_expr_genes(adata2, n_top=20, )

# %%
sc.pp.filter_cells(adata2, min_genes=200)
sc.pp.filter_genes(adata2, min_cells=3)

# %%
adata2.var['mt'] = adata2.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata2, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata2, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(adata2, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata2, x='total_counts', y='n_genes_by_counts')

# %%
adata2 = adata2[adata2.obs.n_genes_by_counts < 2500, :]
adata2 = adata2[adata2.obs.pct_counts_mt < 5, :]

# %%
sc.pp.normalize_total(adata2, target_sum=1e4)
# Out:
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.pp.log1p(adata2)

# %%
sc.pp.highly_variable_genes(adata2, min_mean=0.0125, max_mean=3, min_disp=0.5)

sc.pl.highly_variable_genes(adata2)

# %%
adata2.raw = adata2

# %%
adata2 = adata2[:, adata2.var.highly_variable]

# %%
sc.pp.regress_out(adata2, ['total_counts', 'pct_counts_mt'])

# %%
sc.pp.scale(adata2, max_value=10)

# %%
sc.tl.pca(adata2, svd_solver='arpack')

# %%
sc.pl.pca_variance_ratio(adata2, log=True)

# %%
sc.pp.neighbors(adata2, n_neighbors=10, n_pcs=20)
# Out:
# 2023-06-26 14:43:02.401213: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-26 14:43:02.536560: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-26 14:43:02.537356: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-26 14:43:03.319973: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
sc.tl.louvain(adata2)

# %%
sc.tl.paga(adata2)
sc.pl.paga(adata2, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph
sc.tl.umap(adata2, init_pos='paga')

# %%
adata2
# Out:
# AnnData object with n_obs × n_vars = 111 × 756
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'louvain'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca', 'neighbors', 'louvain', 'paga', 'louvain_sizes', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
#show louvain umap plot
sc.pl.umap(adata2, color=['louvain'])
# Out:
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata2
# Out:
# AnnData object with n_obs × n_vars = 111 × 756
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'louvain'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca', 'neighbors', 'louvain', 'paga', 'louvain_sizes', 'umap', 'louvain_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
metrics=pd.read_csv("/wrk/jacky/organoid/counts/CRISPR_counts/outs/metrics_summary.csv")
metrics
# Out:
#   Estimated Number of Cells Mean Reads per Cell  Median Genes per Cell
# 0                     5,776              30,901                     64  \
#
#   Number of Reads Valid Barcodes Sequencing Saturation Q30 Bases in Barcode
# 0     178,483,533          95.3%                 84.6%                93.0%  \
#
#   Q30 Bases in RNA Read Q30 Bases in UMI Reads Mapped to Genome
# 0                 91.9%            92.3%                  18.1%  \
#
#   Reads Mapped Confidently to Genome
# 0                              13.7%  \
#
#   Reads Mapped Confidently to Intergenic Regions
# 0                                           3.2%  \
#
#   Reads Mapped Confidently to Intronic Regions
# 0                                         2.9%  \
#
#   Reads Mapped Confidently to Exonic Regions
# 0                                       7.7%  \
#
#   Reads Mapped Confidently to Transcriptome Reads Mapped Antisense to Gene
# 0                                      6.0%                           1.5%  \
#
# ...

# %% [markdown]
# ### expression_counts

# %%
exp=sc.read_10x_mtx("/wrk/jacky/organoid/counts/expression_counts/outs/filtered_feature_bc_matrix")
exp
# Out:
# AnnData object with n_obs × n_vars = 8240 × 32285
#     var: 'gene_ids', 'feature_types'

# %%
adata2
# Out:
# AnnData object with n_obs × n_vars = 5776 × 32285
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
sc.pl.highest_expr_genes(exp, n_top=20, )

# %%
sc.pl.highest_expr_genes(adata2, n_top=20, )

# %%
#preprocess the expression data
sc.pp.filter_cells(exp, min_genes=200)
sc.pp.filter_genes(exp, min_cells=3)

exp.var['mt'] = exp.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(exp, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

sc.pl.violin(exp, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
                jitter=0.4, multi_panel=True)

sc.pl.scatter(exp, x='total_counts', y='pct_counts_mt')

sc.pl.scatter(exp, x='total_counts', y='n_genes_by_counts')

exp = exp[exp.obs.n_genes_by_counts < 2500, :]

exp = exp[exp.obs.pct_counts_mt < 5, :]

sc.pp.normalize_total(exp, target_sum=1e4)

sc.pp.log1p(exp)

sc.pp.highly_variable_genes(exp, min_mean=0.0125, max_mean=3, min_disp=0.5)

sc.pl.highly_variable_genes(exp)

exp.raw = exp

exp = exp[:, exp.var.highly_variable]

sc.pp.regress_out(exp, ['total_counts', 'pct_counts_mt'])

sc.pp.scale(exp, max_value=10)

sc.tl.pca(exp, svd_solver='arpack')

sc.pl.pca_variance_ratio(exp, log=True)

sc.pp.neighbors(exp, n_neighbors=10, n_pcs=20)

sc.tl.louvain(exp)

sc.tl.paga(exp)

sc.pl.paga(exp, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph

sc.tl.umap(exp, init_pos='paga')

sc.pl.umap(exp, color=['louvain'])

sc.pl.umap(exp, color=['louvain','n_genes'])
# Out:
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
#do the same for the perturbation data
sc.pp.filter_cells(adata2, min_genes=200)
sc.pp.filter_genes(adata2, min_cells=3)

adata2.var['mt'] = adata2.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata2, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

sc.pl.violin(adata2, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
                jitter=0.4, multi_panel=True)

sc.pl.scatter(adata2, x='total_counts', y='pct_counts_mt')

sc.pl.scatter(adata2, x='total_counts', y='n_genes_by_counts')

adata2 = adata2[adata2.obs.n_genes_by_counts < 2500, :]

adata2 = adata2[adata2.obs.pct_counts_mt < 5, :]

sc.pp.normalize_total(adata2, target_sum=1e4)

sc.pp.log1p(adata2)

sc.pp.highly_variable_genes(adata2, min_mean=0.0125, max_mean=3, min_disp=0.5)

sc.pl.highly_variable_genes(adata2)

adata2.raw = adata2

adata2 = adata2[:, adata2.var.highly_variable]

sc.pp.regress_out(adata2, ['total_counts', 'pct_counts_mt'])

sc.pp.scale(adata2, max_value=10)

sc.tl.pca(adata2, svd_solver='arpack')

sc.pl.pca_variance_ratio(adata2, log=True)

sc.pp.neighbors(adata2, n_neighbors=10, n_pcs=20)

sc.tl.louvain(adata2)

sc.tl.paga(adata2)

sc.pl.paga(adata2, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph

sc.tl.umap(adata2, init_pos='paga')

sc.pl.umap(adata2, color=['louvain'])

sc.pl.umap(adata2, color=['louvain','n_genes'])
# Out:
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sgRNA_data = pd.read_csv("/wrk/jacky/organoid/counts/CRISPR_counts/SI_organoid_KO_genes - For_Bernie.csv", index_col=None,header=None)
sgRNA_data
# Out:
#           0                     1        2
# 0   Ascl2.1  GCGGCGATCTGGAGCAACCG    Ascl2
# 1   Ascl2.2  CGCACCAGAACTCGTAGCAG    Ascl2
# 2   Ascl2.3  GGCTCCAGCGACTCCAGACG    Ascl2
# 3   Ascl2.4  CCAAGTTTACCAGCTTTACG    Ascl2
# 4    Atf3.1  TCAAATACCAGTGACCCAGG     Atf3
# ..      ...                   ...      ...
# 59  Contr.4  ATCCGGGCATAGCGTTTAAA  Control
# 60  Contr.5  GCTTATCGTCATGCGGGTGA  Control
# 61  Contr.6  ACGCTGTTCGTAACCGCGGG  Control
# 62  Contr.7  GCCGTAAGCGGGCCGGTTGA  Control
# 63  Contr.8  TCCTATAATTGAGCGAACGG  Control
#
# [64 rows x 3 columns]

# %%
'Ascl2' in adata2.var_names
# Out:
# False
