# %%
import pandas as pd
import scanpy as sc

# %%
exp=sc.read_h5ad('/wrk/jacky/organoid/counts/expression_counts/outs/filtered_feature_bc_matrix/filtered_feature_bc_matrix.h5ad')
exp
# Out:
# AnnData object with n_obs × n_vars = 3623 × 16771
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'louvain'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'log1p', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
#dotplot 
sc.pl.dotplot(exp, ['Lgr5','Alpi','Muc2','Lyz1','Chga','Ascl2','Olfm4','Myc','Reg3b','Reg3a'], groupby='louvain')
# Out:
# /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)
